# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('C:/Users/Admin/Downloads/1. Weather Data.csv')

# %%
data.head(5)
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
#
#    Visibility_km  Press_kPa               Weather
# 0            8.0     101.24                   Fog
# 1            8.0     101.24                   Fog
# 2            4.0     101.26  Freezing Drizzle,Fog
# 3            4.0     101.27  Freezing Drizzle,Fog
# 4            4.8     101.23                   Fog

# %%
data.shape
# Out:
# (8784, 8)

# %%
data.columns
# Out:
# Index(['Date/Time', 'Temp_C', 'Dew Point Temp_C', 'Rel Hum_%',
#        'Wind Speed_km/h', 'Visibility_km', 'Press_kPa', 'Weather'],
#       dtype='object')

# %%
data['Weather'].head()
# Out:
# 0                     Fog
# 1                     Fog
# 2    Freezing Drizzle,Fog
# 3    Freezing Drizzle,Fog
# 4                     Fog
# Name: Weather, dtype: object

# %%
data.index
# Out:
# RangeIndex(start=0, stop=8784, step=1)

# %%
rng= pd.date_range(start='1/1/2017', freq='B', periods=8785)
data.reindex()
# Out:
#              Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0        1/1/2012 0:00    -1.8              -3.9         86                4
# 1        1/1/2012 1:00    -1.8              -3.7         87                4
# 2        1/1/2012 2:00    -1.8              -3.4         89                7
# 3        1/1/2012 3:00    -1.5              -3.2         88                6
# 4        1/1/2012 4:00    -1.5              -3.3         88                7
# ...                ...     ...               ...        ...              ...
# 8779  12/31/2012 19:00     0.1              -2.7         81               30
# 8780  12/31/2012 20:00     0.2              -2.4         83               24
# 8781  12/31/2012 21:00    -0.5              -1.5         93               28
# 8782  12/31/2012 22:00    -0.2              -1.8         89               28
# 8783  12/31/2012 23:00     0.0              -2.1         86               30
#
# ...

# %%
data[0:1].nunique
# Out:
# <bound method DataFrame.nunique of        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
#
#    Visibility_km  Press_kPa Weather
# 0            8.0     101.24     Fog  >

# %%
data.value_counts().head()
# Out:
# Date/Time       Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  Visibility_km  Press_kPa  Weather
# 1/1/2012 0:00   -1.8    -3.9              86         4                8.0            101.24     Fog            1
# 6/1/2012 12:00   19.3    3.3              35         20               48.3           101.32     Cloudy         1
# 5/9/2012 7:00    14.3    12.5             89         15               4.8            100.12     Fog            1
# 5/9/2012 8:00    14.3    12.3             88         17               6.4            100.12     Fog            1
# 5/9/2012 9:00    14.0    12.3             89         9                4.0            100.10     Drizzle,Fog    1
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8784 entries, 0 to 8783
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Date/Time         8784 non-null   object
#  1   Temp_C            8784 non-null   float64
#  2   Dew Point Temp_C  8784 non-null   float64
#  3   Rel Hum_%         8784 non-null   int64
#  4   Wind Speed_km/h   8784 non-null   int64
#  5   Visibility_km     8784 non-null   float64
#  6   Press_kPa         8784 non-null   float64
#  7   Weather           8784 non-null   object
# dtypes: float64(4), int64(2), object(2)
# memory usage: 549.1+ KB

# %%
data.describe()
# Out:
#             Temp_C  Dew Point Temp_C    Rel Hum_%  Wind Speed_km/h  \
# count  8784.000000       8784.000000  8784.000000      8784.000000
# mean      8.798144          2.555294    67.431694        14.945469
# std      11.687883         10.883072    16.918881         8.688696
# min     -23.300000        -28.500000    18.000000         0.000000
# 25%       0.100000         -5.900000    56.000000         9.000000
# 50%       9.300000          3.300000    68.000000        13.000000
# 75%      18.800000         11.800000    81.000000        20.000000
# max      33.000000         24.400000   100.000000        83.000000
#
#        Visibility_km    Press_kPa
# count    8784.000000  8784.000000
# mean       27.664447   101.051623
# std        12.622688     0.844005
# min         0.200000    97.520000
# 25%        24.100000   100.560000
# 50%        25.000000   101.070000
# 75%        25.000000   101.590000
# max        48.300000   103.650000

# %%
data_weather = data[data['Weather']=='Clear']
data_weather.head()
# Out:
#           Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 67   1/3/2012 19:00   -16.9             -24.8         50               24
# 114  1/5/2012 18:00    -7.1             -14.4         56               11
# 115  1/5/2012 19:00    -9.2             -15.4         61                7
# 116  1/5/2012 20:00    -9.8             -15.7         62                9
# 117  1/5/2012 21:00    -9.0             -14.8         63               13
#
#      Visibility_km  Press_kPa Weather
# 67            25.0     101.74   Clear
# 114           25.0     100.71   Clear
# 115           25.0     100.80   Clear
# 116           25.0     100.83   Clear
# 117           25.0     100.83   Clear

# %%
wind_speed_4= data[data['Wind Speed_km/h']==4]
wind_speed_4.count()
# Out:
# Date/Time           474
# Temp_C              474
# Dew Point Temp_C    474
# Rel Hum_%           474
# Wind Speed_km/h     474
# Visibility_km       474
# Press_kPa           474
# Weather             474
# dtype: int64

# %%
clear= data.groupby('Weather').get_group('Clear')
clear.count()
# Out:
# Date/Time           1326
# Temp_C              1326
# Dew Point Temp_C    1326
# Rel Hum_%           1326
# Wind Speed_km/h     1326
# Visibility_km       1326
# Press_kPa           1326
# Weather             1326
# dtype: int64

# %%
data.groupby('Wind Speed_km/h').get_group(4).count()
#filtering out through group by and further filteration by using get_group()
# Out:
# Date/Time           474
# Temp_C              474
# Dew Point Temp_C    474
# Rel Hum_%           474
# Wind Speed_km/h     474
# Visibility_km       474
# Press_kPa           474
# Weather             474
# dtype: int64

# %%
data[data.isnull()].sum()
# Out:
# Date/Time             0
# Temp_C              0.0
# Dew Point Temp_C    0.0
# Rel Hum_%           0.0
# Wind Speed_km/h     0.0
# Visibility_km       0.0
# Press_kPa           0.0
# Weather               0
# dtype: object

# %%
data['Weather_condition']= data['Weather'].rename('Weather_Condition')
data.head(2)
#for creating a new column
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Weather_condition
# 0            8.0     101.24     Fog               Fog
# 1            8.0     101.24     Fog               Fog

# %%
data.rename(columns={'Weather': 'weatheroutput'}).head(1)
#for renaming the column name values
# Out:
#        Date/Time  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
#
#    Visibility_km  Press_kPa weatheroutput Weather_condition
# 0            8.0     101.24           Fog               Fog

# %%
data.rename(columns= {'Date/Time': 'Date'}, inplace=True)

# %%
data['Wind Speed_km/h'].mean()
# Out:
# 14.94546903460838

# %%
data.head(0)
# Out:
# Empty DataFrame
# Columns: [Date, Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather, Weather_condition]
# Index: []

# %%
data['Press_kPa'].std()
# Out:
# 0.8440047459486483

# %%
data['Rel Hum_%'].var()
# Out:
# 286.24855019850196

# %%
data['Weather'].value_counts().head()
# Out:
# Mainly Clear     2106
# Mostly Cloudy    2069
# Cloudy           1728
# Clear            1326
# Snow              390
# Name: Weather, dtype: int64

# %%
data[data['Weather']=='Snow'].head(1)
# Out:
#              Date  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 55  1/3/2012 7:00   -14.0             -19.5         63               19
#
#     Visibility_km  Press_kPa Weather Weather_condition
# 55           25.0     100.95    Snow              Snow

# %%
data_xyz = data[(data['Wind Speed_km/h']>=24) & (data['Visibility_km']==25)]
data_xyz.head(1)
# Out:
#               Date  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 23  1/1/2012 23:00     5.3               2.0         79               30
#
#     Visibility_km  Press_kPa Weather Weather_condition
# 23           25.0      99.31  Cloudy            Cloudy

# %%
data[data['Visibility_km']==25].head(1)
# Out:
#               Date  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 20  1/1/2012 20:00     3.2               1.3         87               19
#
#     Visibility_km  Press_kPa Weather Weather_condition
# 20           25.0       99.5  Cloudy            Cloudy

# %%
data[data['Weather'].str.contains('Snow')].head(1)
# Out:
#               Date  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 41  1/2/2012 17:00    -2.1              -9.5         57               22
#
#     Visibility_km  Press_kPa       Weather Weather_condition
# 41           25.0      99.66  Snow Showers      Snow Showers

# %%
data.mean()
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9116\531903386.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.mean()
# Temp_C                8.798144
# Dew Point Temp_C      2.555294
# Rel Hum_%            67.431694
# Wind Speed_km/h      14.945469
# Visibility_km        27.664447
# Press_kPa           101.051623
# dtype: float64

# %%
data.groupby('Weather').mean().head(2)
# Out:
#            Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# Weather
# Clear    6.825716          0.089367  64.497738        10.557315
# Cloudy   7.970544          2.375810  69.592593        16.127315
#
#          Visibility_km   Press_kPa
# Weather
# Clear        30.153243  101.587443
# Cloudy       26.625752  100.911441

# %%
x= data.min()
y= data.max()
print(x)
print(y)
# Out:
# Date                 1/1/2012 0:00
# Temp_C                       -23.3
# Dew Point Temp_C             -28.5
# Rel Hum_%                       18
# Wind Speed_km/h                  0
# Visibility_km                  0.2
# Press_kPa                    97.52
# Weather                      Clear
# Weather_condition            Clear
# dtype: object
# Date                          9/9/2012 9:00
# Temp_C                                 33.0
# Dew Point Temp_C                       24.4
# Rel Hum_%                               100
# Wind Speed_km/h                          83
# Visibility_km                          48.3
# Press_kPa                            103.65
# Weather              Thunderstorms,Rain,Fog
# Weather_condition    Thunderstorms,Rain,Fog
# dtype: object

# %%
fog= data['Weather'].str.contains('Fog')
fog.head(1)
# Out:
# 0    True
# Name: Weather, dtype: bool

# %%
data[(data['Weather']=='clear') & (data['Visibility_km']>40)]
# Out:
# Empty DataFrame
# Columns: [Date, Temp_C, Dew Point Temp_C, Rel Hum_%, Wind Speed_km/h, Visibility_km, Press_kPa, Weather, Weather_condition]
# Index: []

# %%
data[(data['Weather']=='Clear') & (data['Rel Hum_%']> 50) | (data['Visibility_km']> 40)].head(2)
# Out:
#                Date  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 106  1/5/2012 10:00    -6.0             -10.0         73               17
# 107  1/5/2012 11:00    -5.6             -10.2         70               22
#
#      Visibility_km  Press_kPa       Weather Weather_condition
# 106           48.3     100.45  Mainly Clear      Mainly Clear
# 107           48.3     100.41  Mainly Clear      Mainly Clear

# %%
sns.relplot(data=data, x = 'Visibility_km', y='Press_kPa', hue='Weather', style='Visibility_km',height= 3.5)

# %%
sns.catplot(kind='bar', data=data, x='Visibility_km', y='Press_kPa', facet_kws=dict(sharex=False), height=3.5)

# %%
sns.displot(data=data, y='Rel Hum_%', x='Temp_C', kind='kde', height= 3.5)

# %%
sns.set_style('darkgrid')

# %%
sns.barplot(data=data, x='Weather', y='Rel Hum_%' )
# Out:
# <AxesSubplot: xlabel='Weather', ylabel='Rel Hum_%'>

# %%
# how to build the confidence intervals at the top of the these graphs via bootstrapping where they got to know that 90% of the results lies in that
# to disable the confidence intervals we can choose the ci = None 
# use of estimator = np.std

sns.barplot(data=data, x= 'Weather', y='Rel Hum_%', ci=70, estimator=np.std)
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_9116\3073003546.py:5: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=('ci', 70)` for the same effect.
#
#   sns.barplot(data=data, x= 'Weather', y='Rel Hum_%', ci=70, estimator=np.std)
# <AxesSubplot: xlabel='Weather', ylabel='Rel Hum_%'>

# %%
data.head(2)
# Out:
#             Date  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
#
#    Visibility_km  Press_kPa Weather Weather_condition
# 0            8.0     101.24     Fog               Fog
# 1            8.0     101.24     Fog               Fog

# %%
sns.jointplot(data=data, x= 'Visibility_km', y='Press_kPa')
#multivariate analysis using jointplot

# %%
data.head(10)
# Out:
#             Date  Temp_C  Dew Point Temp_C  Rel Hum_%  Wind Speed_km/h  \
# 0  1/1/2012 0:00    -1.8              -3.9         86                4
# 1  1/1/2012 1:00    -1.8              -3.7         87                4
# 2  1/1/2012 2:00    -1.8              -3.4         89                7
# 3  1/1/2012 3:00    -1.5              -3.2         88                6
# 4  1/1/2012 4:00    -1.5              -3.3         88                7
# 5  1/1/2012 5:00    -1.4              -3.3         87                9
# 6  1/1/2012 6:00    -1.5              -3.1         89                7
# 7  1/1/2012 7:00    -1.4              -3.6         85                7
# 8  1/1/2012 8:00    -1.4              -3.6         85                9
# 9  1/1/2012 9:00    -1.3              -3.1         88               15
#
#    Visibility_km  Press_kPa               Weather     Weather_condition
# 0            8.0     101.24                   Fog                   Fog
# ...

# %%
g = sns.JointGrid(data=data, x='Wind Speed_km/h', y='Visibility_km', hue='Wind Speed_km/h', height=7)
g.plot(sns.scatterplot, sns.violinplot)

# %%
type(g)
#type(x) for checking the data type of x
# Out:
# seaborn.axisgrid.JointGrid

# %%
c= sns.JointGrid(x='Wind Speed_km/h', y='Visibility_km', data=data, height=3.5)
c.plot(sns.relplot, sns.kdeplot)
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python310\lib\site-packages\seaborn\relational.py:852: UserWarning: relplot is a figure-level function and does not accept the `ax` parameter. You may wish to try scatterplot
#   warnings.warn(msg, UserWarning)

# %%
# !ls
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.
